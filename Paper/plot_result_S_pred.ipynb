# %%
import json


def load_json_file(file):
    with open(file, 'r') as f:
        data = json.load(f)
    return data

result = load_json_file(r'C:\Users\rehan\meine_Repos\Masterarbeit\Paper\results\(n_train)2000__(B_RF)1000__(B_1)0__(zero_weights)0.29\result_dict_variante1.json')
